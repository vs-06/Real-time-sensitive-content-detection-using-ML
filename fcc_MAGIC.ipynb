# %% [markdown]
# <a href="https://colab.research.google.com/github/vs-06/Real-time-sensitive-content-detection-using-ML/blob/main/fcc_MAGIC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
